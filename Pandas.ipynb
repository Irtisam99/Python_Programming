# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: C:\Users\HP\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
"""
 Pandas Dataframe : A data structure for tabular data
"""
health_data_table={
    "height":[5.5,5.5,'A',5.8],
    "weight":[57,62,72,75],
    "bmi":[19.3,12.7,20.3,None],
    'smoker':['Yes','no',None,'Yes']
}

# %%
health_data_table.keys()
# Out:
# dict_keys(['height', 'weight', 'bmi', 'smoker'])

# %%
health_data_table.values()
# Out:
# dict_values([[5.5, 5.5, 'A', 5.8], [57, 62, 72, 75], [19.3, 12.7, 20.3, None], ['Yes', 'no', None, 'Yes']])

# %%
health_data_frame=pd.DataFrame(health_data_table)

# %%
health_data_frame.head(2)
# Out:
#   height  weight   bmi smoker
# 0    5.5      57  19.3    Yes
# 1    5.5      62  12.7     no

# %%
health_data_frame.tail(3)
# Out:
#   height  weight   bmi smoker
# 1    5.5      62  12.7     no
# 2      A      72  20.3    NaN
# 3    5.8      75   NaN    Yes

# %%
health_data_frame.shape
# Out:
# (4, 4)

# %%
health_data_frame.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   height  4 non-null      object
#  1   weight  4 non-null      int64
#  2   bmi     3 non-null      float64
#  3   smoker  3 non-null      str
# dtypes: float64(1), int64(1), object(1), str(1)
# memory usage: 260.0+ bytes

# %%
# Statistical Summary
health_data_frame.describe()
# Out:
#          weight        bmi
# count   4.00000   3.000000
# mean   66.50000  17.433333
# std     8.42615   4.129568
# min    57.00000  12.700000
# 25%    60.75000  16.000000
# 50%    67.00000  19.300000
# 75%    72.75000  19.800000
# max    75.00000  20.300000

# %%
health_data_np_array=health_data_frame.values
print(health_data_np_array)
print(type(health_data_np_array))
# Out:
# [[5.5 57 19.3 'Yes']
#  [5.5 62 12.7 'no']
#  ['A' 72 20.3 nan]
#  [5.8 75 nan 'Yes']]
# <class 'numpy.ndarray'>

# %%
print(health_data_frame.columns)
print(type(health_data_frame.columns))
# Out:
# Index(['height', 'weight', 'bmi', 'smoker'], dtype='str')
# <class 'pandas.Index'>

# %%
"""
Google Framework for Data Analysis
Ask- Hypothesis Formulate
Prepare-Clean
Process-Transform
Analyze- Analyze the date to find the answers
Share- Share the answers visually with stakeholders
Act- Plan of action
"""
health_data_frame.columns=["Height (Feet)","Weight (kg)","BMI","Is Smoker"]
health_data_frame
# Out:
#   Height (Feet)  Weight (kg)   BMI Is Smoker
# 0           5.5           57  19.3       Yes
# 1           5.5           62  12.7        no
# 2             A           72  20.3       NaN
# 3           5.8           75   NaN       Yes

# %%
health_data_frame.to_csv(
    "E:\\BongoDev\\Python-Programming\\my_saved_df.csv",
    index=False,
)

# %%
my_saved_df=pd.read_csv("E:\\BongoDev\\Python-Programming\\my_saved_df.csv" )
my_saved_df.head()
# Out:
#   Height (Feet)  Weight (kg)   BMI Is Smoker
# 0           5.5           57  19.3       Yes
# 1           5.5           62  12.7        no
# 2             A           72  20.3       NaN
# 3           5.8           75   NaN       Yes

# %%
df=pd.read_csv("E:\\BongoDev\\Python-Programming\\homelessness.csv")
print(type(df))
df.head()
# Out:
# <class 'pandas.DataFrame'>
#    Unnamed: 0              region       state  individuals  family_members  \
# 0           0  East South Central     Alabama       2570.0           864.0
# 1           1             Pacific      Alaska       1434.0           582.0
# 2           2            Mountain     Arizona       7259.0          2606.0
# 3           3  West South Central    Arkansas       2280.0           432.0
# 4           4             Pacific  California     109008.0         20964.0
#
#    state_pop
# 0    4887681
# 1     735139
# 2    7158024
# 3    3009733
# 4   39461588

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      51 non-null     int64
#  1   region          51 non-null     str
#  2   state           51 non-null     str
#  3   individuals     51 non-null     float64
#  4   family_members  51 non-null     float64
#  5   state_pop       51 non-null     int64
# dtypes: float64(2), int64(2), str(2)
# memory usage: 2.5 KB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'region', 'state', 'individuals', 'family_members',
#        'state_pop'],
#       dtype='str')

# %%
sorted_df_by_cols=df.sort_values(
    by=["region",'state'],
    ascending=[False,True],

)
sorted_df_by_cols.head(50)
# Out:
#     Unnamed: 0              region                 state  individuals  \
# 3            3  West South Central              Arkansas       2280.0
# 18          18  West South Central             Louisiana       2540.0
# 36          36  West South Central              Oklahoma       2823.0
# 43          43  West South Central                 Texas      19199.0
# 15          15  West North Central                  Iowa       1711.0
# 16          16  West North Central                Kansas       1443.0
# 23          23  West North Central             Minnesota       3993.0
# 25          25  West North Central              Missouri       3776.0
# 27          27  West North Central              Nebraska       1745.0
# 34          34  West North Central          North Dakota        467.0
# 41          41  West North Central          South Dakota        836.0
# 7            7      South Atlantic              Delaware        708.0
# ...

# %%
# Pandas Dataframe is a collection of series data structure(col)

individuals=df['individuals']
print(type(individuals))
print(individuals)
# Out:
# <class 'pandas.Series'>
# 0       2570.0
# 1       1434.0
# 2       7259.0
# 3       2280.0
# 4     109008.0
# 5       7607.0
# 6       2280.0
# 7        708.0
# 8       3770.0
# 9      21443.0
# 10      6943.0
# 11      4131.0
# 12      1297.0
# 13      6752.0
# 14      3776.0
# 15      1711.0
# 16      1443.0
# 17      2735.0
# 18      2540.0
# 19      1450.0
# 20      4914.0
# 21      6811.0
# 22      5209.0
# 23      3993.0
# 24      1024.0
# 25      3776.0
# 26       983.0
# 27      1745.0
# 28      7058.0
# 29       835.0
# 30      6048.0
# 31      1949.0
# 32     39827.0
# 33      6451.0
# 34       467.0
# 35      6929.0
# 36      2823.0
# 37     11139.0
# 38      8163.0
# 39       747.0
# 40      3082.0
# 41       836.0
# 42      6139.0
# 43     19199.0
# 44      1904.0
# 45       780.0
# 46      3928.0
# 47     16424.0
# 48      1021.0
# 49      2740.0
# 50       434.0
# Name: individuals, dtype: float64

# %%
new_df=df[['region','family_members']]
new_df.head()
# Out:
#                region  family_members
# 0  East South Central           864.0
# 1             Pacific           582.0
# 2            Mountain          2606.0
# 3  West South Central           432.0
# 4             Pacific         20964.0

# %%
# Selecting ROws

mask=df['region']=='Mountain'
df_mountain=df[mask]
df_mountain.head()
# Out:
#     Unnamed: 0    region     state  individuals  family_members  state_pop
# 2            2  Mountain   Arizona       7259.0          2606.0    7158024
# 5            5  Mountain  Colorado       7607.0          3250.0    5691287
# 12          12  Mountain     Idaho       1297.0           715.0    1750536
# 26          26  Mountain   Montana        983.0           422.0    1060665
# 28          28  Mountain    Nevada       7058.0           486.0    3027341

# %%
df_gt_10k=df[df['individuals']>10000]
df_gt_10k.head()
# Out:
#     Unnamed: 0              region       state  individuals  family_members  \
# 4            4             Pacific  California     109008.0         20964.0
# 9            9      South Atlantic     Florida      21443.0          9587.0
# 32          32        Mid-Atlantic    New York      39827.0         52070.0
# 37          37             Pacific      Oregon      11139.0          3337.0
# 43          43  West South Central       Texas      19199.0          6111.0
#
#     state_pop
# 4    39461588
# 9    21244317
# 32   19530351
# 37    4181886
# 43   28628666

# %%
is_family_lt_1k_mask=df['family_members']<10000
is_region_pacific_mask=df['region']=='Pacific'

new_df=df[is_family_lt_1k_mask & is_region_pacific_mask]
new_df.head()
# Out:
#    Unnamed: 0   region     state  individuals  family_members  state_pop
# 0           0  Pacific   Alabama       2570.0           864.0    4887681
# 1           1  Pacific    Alaska       1434.0           582.0     735139
# 2           2  Pacific   Arizona       7259.0          2606.0    7158024
# 3           3  Pacific  Arkansas       2280.0           432.0    3009733
# 5           5  Pacific  Colorado       7607.0          3250.0    5691287

# %%
df['total_population']=df['individuals']+df['state_pop']
df.head()
# Out:
#    Unnamed: 0   region       state  individuals  family_members  state_pop  \
# 0           0  Pacific     Alabama       2570.0           864.0    4887681
# 1           1  Pacific      Alaska       1434.0           582.0     735139
# 2           2  Pacific     Arizona       7259.0          2606.0    7158024
# 3           3  Pacific    Arkansas       2280.0           432.0    3009733
# 4           4  Pacific  California     109008.0         20964.0   39461588
#
#    total_population
# 0         4890251.0
# 1          736573.0
# 2         7165283.0
# 3         3012013.0
# 4        39570596.0

# %%
df.query(
    "family_members<10000 and region=='Pacific'",

)
# Out:
#     Unnamed: 0   region                 state  individuals  family_members  \
# 0            0  Pacific               Alabama       2570.0           864.0
# 1            1  Pacific                Alaska       1434.0           582.0
# 2            2  Pacific               Arizona       7259.0          2606.0
# 3            3  Pacific              Arkansas       2280.0           432.0
# 5            5  Pacific              Colorado       7607.0          3250.0
# 6            6  Pacific           Connecticut       2280.0          1696.0
# 7            7  Pacific              Delaware        708.0           374.0
# 8            8  Pacific  District of Columbia       3770.0          3134.0
# 9            9  Pacific               Florida      21443.0          9587.0
# 10          10  Pacific               Georgia       6943.0          2556.0
# 11          11  Pacific                Hawaii       4131.0          2399.0
# ...

# %%
df=df.drop(columns='Unnamed: 0')
df.head()
# Out:
#     region       state  individuals  family_members  state_pop  \
# 0  Pacific     Alabama       2570.0           864.0    4887681
# 1  Pacific      Alaska       1434.0           582.0     735139
# 2  Pacific     Arizona       7259.0          2606.0    7158024
# 3  Pacific    Arkansas       2280.0           432.0    3009733
# 4  Pacific  California     109008.0         20964.0   39461588
#
#    total_population
# 0         4890251.0
# 1          736573.0
# 2         7165283.0
# 3         3012013.0
# 4        39570596.0

# %%
df['individuals'].min()
# Out:
# np.float64(434.0)

# %%
df['individuals'].max()
# Out:
# np.float64(109008.0)

# %%
df['individuals'].std()
# Out:
# np.float64(15991.025083231812)

# %%
df['individuals'].quantile(0.75)
# Out:
# np.float64(6781.5)

# %%
df.describe()
# Out:
#          individuals  family_members     state_pop  total_population
# count      51.000000       51.000000  5.100000e+01      5.100000e+01
# mean     7225.784314     3504.882353  6.405637e+06      6.412863e+06
# std     15991.025083     7805.411811  7.327258e+06      7.340615e+06
# min       434.000000       75.000000  5.776010e+05      5.780350e+05
# 25%      1446.500000      592.000000  1.777414e+06      1.778572e+06
# 50%      3082.000000     1482.000000  4.461153e+06      4.463888e+06
# 75%      6781.500000     3196.000000  7.340946e+06      7.352788e+06
# max    109008.000000    52070.000000  3.946159e+07      3.957060e+07

# %%
# Zero Mean and Unit Variance

def normalize(col):
    mean=col.mean(),
    std=col.std()
    return (col-mean)/std

# %%
normalize(df['individuals'])
# Out:
# 0    -0.291150
# 1    -0.362190
# 2     0.002077
# 3    -0.309285
# 4     6.364959
# 5     0.023839
# 6    -0.309285
# 7    -0.407590
# 8    -0.216108
# 9     0.889075
# 10   -0.017684
# 11   -0.193533
# 12   -0.370757
# 13   -0.029628
# 14   -0.215733
# 15   -0.344867
# 16   -0.361627
# 17   -0.280832
# 18   -0.293026
# 19   -0.361189
# 20   -0.144568
# 21   -0.025939
# 22   -0.126120
# 23   -0.202162
# 24   -0.387829
# 25   -0.215733
# 26   -0.390393
# 27   -0.342741
# 28   -0.010492
# 29   -0.399648
# 30   -0.073653
# 31   -0.329984
# 32    2.038720
# 33   -0.048451
# 34   -0.422661
# 35   -0.018559
# 36   -0.275328
# 37    0.244713
# 38    0.058609
# 39   -0.405151
# 40   -0.259132
# 41   -0.399586
# 42   -0.067962
# 43    0.748746
# 44   -0.332798
# 45   -0.403088
# 46   -0.206227
# 47    0.575211
# 48   -0.388017
# 49   -0.280519
# 50   -0.424725
# Name: individuals, dtype: float64
